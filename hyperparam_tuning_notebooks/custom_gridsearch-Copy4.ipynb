# %%
import tensorflow as tf
# from tensorboard.plugins.hparams import api as hp
from tensorflow import keras

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
ratings = pd.read_pickle("./Data/small_random_selection_longform.pkl")

# %%
user_enc = LabelEncoder()
ratings['user'] = user_enc.fit_transform(ratings['user_id'].values)
n_users = ratings['user'].nunique()
n_users
# Out:
# 37235

# %%
item_enc = LabelEncoder()
ratings['movie'] = item_enc.fit_transform(ratings['movie_id'].values)
n_movies = ratings['movie'].nunique()
n_movies
# Out:
# 29758

# %%
nmovie_id = ratings.movie_id.nunique()
nuser_id = ratings.user_id.nunique()

# %%
X_train, X_test = train_test_split(ratings[['movie', 'user', 'rating_score']], test_size=0.3, random_state=42)

# %%
len(X_train)
# Out:
# 388607

# %%
l2_1 = keras.regularizers.l2(.1)
l2_01 = 'l2'
l2_001 = keras.regularizers.l2(.001)

# %%
HP_NUM_UNITS = [32, 64, 128]
HP_DROPOUT = [.3]
HP_LEARNING_RATE = [.1, .01, .001]
HP_REGULARIZER = [l2_1]

# %%
def train_test_model(hparams):
    
    input_movies = keras.layers.Input(shape=[1])
    embed_movies = keras.layers.Embedding(nmovie_id+1, 15)(input_movies)
    movies_out = keras.layers.Flatten()(embed_movies)

    input_users = keras.layers.Input(shape=[1])
    embed_users = keras.layers.Embedding(nuser_id+1, 15)(input_users)
    users_out = keras.layers.Flatten()(embed_users)

    conc_layer = keras.layers.Concatenate()([movies_out, users_out])
    x = keras.layers.Dense(hparams['HP_NUM_UNITS'], 
                           activation='relu', 
                           kernel_regularizer=hparams['HP_REGULARIZER'])(conc_layer)
    dropout = x = keras.layers.Dropout(rate=hparams['HP_DROPOUT'], seed=42)(x)
    x_out = x = keras.layers.Dense(1, 
                                   activation='relu',
                                  kernel_regularizer=hparams['HP_REGULARIZER'])(x)

    model = keras.Model([input_movies, input_users], x_out)
    
    opt = tf.optimizers.Adam(learning_rate=hparams['HP_LEARNING_RATE'])
    model.compile(optimizer=opt, loss='mean_squared_error', metrics = keras.metrics.RootMeanSquaredError())
    
    hist = model.fit([X_train.movie, X_train.user], 
                 X_train.rating_score,  
                 batch_size=len(X_train), epochs=20, validation_split=.2)

#     print(hist.history['val_mean_squared_error'])
    return hist

# %%
run_history = {}

session_num = 0

for num_units in HP_NUM_UNITS:
    for dropout_rate in HP_DROPOUT:
        for learning_rate in HP_LEARNING_RATE:
            for regularization in HP_REGULARIZER:
                hparams = {
                'HP_NUM_UNITS': num_units,
                'HP_DROPOUT': dropout_rate,
                'HP_LEARNING_RATE': learning_rate,
                'HP_REGULARIZER': regularization,
                }
                
                run_name = "run-{}".format(session_num)
                print("----Starting trial: {}".format(run_name))
                print(hparams)
                
                output = train_test_model(hparams,)
                run_history[run_name] = {
                    'params': hparams,
                    'output': output,
                }
                session_num += 1
# Out:
# ----Starting trial: run-0
# {'HP_NUM_UNITS': 32, 'HP_DROPOUT': 0.3, 'HP_LEARNING_RATE': 0.1, 'HP_REGULARIZER': <tensorflow.python.keras.regularizers.L2 object at 0x7fc3be6db070>}
# Epoch 1/20
# 1/1 [==============================] - 3s 3s/step - loss: 18.8356 - root_mean_squared_error: 3.9337 - val_loss: 14.8146 - val_root_mean_squared_error: 3.6959
# Epoch 2/20
# 1/1 [==============================] - 1s 544ms/step - loss: 14.8396 - root_mean_squared_error: 3.6993 - val_loss: 10.6857 - val_root_mean_squared_error: 3.2007
# Epoch 3/20
# 1/1 [==============================] - 0s 401ms/step - loss: 10.6891 - root_mean_squared_error: 3.2012 - val_loss: 4.4419 - val_root_mean_squared_error: 1.9332
# Epoch 4/20
# 1/1 [==============================] - 0s 430ms/step - loss: 4.5194 - root_mean_squared_error: 1.9531 - val_loss: 5.5287 - val_root_mean_squared_error: 1.9984
# Epoch 5/20
# 1/1 [==============================] - 0s 393ms/step - loss: 6.9217 - root_mean_squared_error: 2.3209 - val_loss: 3.1633 - val_root_mean_squared_error: 1.3159
# Epoch 6/20
# 1/1 [==============================] - 0s 367ms/step - loss: 3.9748 - root_mean_squared_error: 1.5947 - val_loss: 2.2453 - val_root_mean_squared_error: 1.0561
# Epoch 7/20
# 1/1 [==============================] - 0s 377ms/step - loss: 2.5234 - root_mean_squared_error: 1.1804 - val_loss: 3.0799 - val_root_mean_squared_error: 1.4902
# Epoch 8/20
# 1/1 [==============================] - 0s 391ms/step - loss: 3.1927 - root_mean_squared_error: 1.5276 - val_loss: 3.3606 - val_root_mean_squared_error: 1.6428
# Epoch 9/20
# 1/1 [==============================] - 0s 353ms/step - loss: 3.4459 - root_mean_squared_error: 1.6686 - val_loss: 2.8258 - val_root_mean_squared_error: 1.5113
# Epoch 10/20
# 1/1 [==============================] - 0s 395ms/step - loss: 2.9358 - root_mean_squared_error: 1.5472 - val_loss: 1.9121 - val_root_mean_squared_error: 1.1843
# Epoch 11/20
# 1/1 [==============================] - 0s 398ms/step - loss: 2.0901 - root_mean_squared_error: 1.2572 - val_loss: 1.4193 - val_root_mean_squared_error: 0.9259
# Epoch 12/20
# 1/1 [==============================] - 0s 405ms/step - loss: 1.7439 - root_mean_squared_error: 1.0872 - val_loss: 1.7599 - val_root_mean_squared_error: 1.0676
# Epoch 13/20
# 1/1 [==============================] - 0s 424ms/step - loss: 2.2337 - root_mean_squared_error: 1.2703 - val_loss: 1.7755 - val_root_mean_squared_error: 1.0856
# Epoch 14/20
# 1/1 [==============================] - 0s 458ms/step - loss: 2.2143 - root_mean_squared_error: 1.2717 - val_loss: 1.3776 - val_root_mean_squared_error: 0.9281
# Epoch 15/20
# 1/1 [==============================] - 1s 535ms/step - loss: 1.6661 - root_mean_squared_error: 1.0723 - val_loss: 1.3273 - val_root_mean_squared_error: 0.9478
# Epoch 16/20
# 1/1 [==============================] - 0s 461ms/step - loss: 1.4925 - root_mean_squared_error: 1.0312 - val_loss: 1.5631 - val_root_mean_squared_error: 1.0961
# Epoch 17/20
# 1/1 [==============================] - 0s 385ms/step - loss: 1.6689 - root_mean_squared_error: 1.1434 - val_loss: 1.6702 - val_root_mean_squared_error: 1.1651
# Epoch 18/20
# 1/1 [==============================] - 0s 405ms/step - loss: 1.7602 - root_mean_squared_error: 1.2032 - val_loss: 1.5139 - val_root_mean_squared_error: 1.1112
# Epoch 19/20
# 1/1 [==============================] - 0s 480ms/step - loss: 1.6064 - root_mean_squared_error: 1.1520 - val_loss: 1.2528 - val_root_mean_squared_error: 0.9943
# Epoch 20/20
# 1/1 [==============================] - 0s 400ms/step - loss: 1.3660 - root_mean_squared_error: 1.0497 - val_loss: 1.1219 - val_root_mean_squared_error: 0.9241
# ----Starting trial: run-1
# {'HP_NUM_UNITS': 32, 'HP_DROPOUT': 0.3, 'HP_LEARNING_RATE': 0.01, 'HP_REGULARIZER': <tensorflow.python.keras.regularizers.L2 object at 0x7fc3be6db070>}
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 18.6318 - root_mean_squared_error: 3.9153 - val_loss: 17.7597 - val_root_mean_squared_error: 3.8405
# Epoch 2/20
# 1/1 [==============================] - 0s 379ms/step - loss: 17.7828 - root_mean_squared_error: 3.8435 - val_loss: 16.8734 - val_root_mean_squared_error: 3.7588
# Epoch 3/20
# 1/1 [==============================] - 0s 391ms/step - loss: 16.8901 - root_mean_squared_error: 3.7611 - val_loss: 15.9504 - val_root_mean_squared_error: 3.6662
# Epoch 4/20
# 1/1 [==============================] - 0s 394ms/step - loss: 15.9604 - root_mean_squared_error: 3.6676 - val_loss: 14.9613 - val_root_mean_squared_error: 3.5568
# Epoch 5/20
# 1/1 [==============================] - 0s 420ms/step - loss: 14.9670 - root_mean_squared_error: 3.5576 - val_loss: 13.8809 - val_root_mean_squared_error: 3.4253
# Epoch 6/20
# 1/1 [==============================] - 0s 392ms/step - loss: 13.8775 - root_mean_squared_error: 3.4248 - val_loss: 12.6924 - val_root_mean_squared_error: 3.2669
# Epoch 7/20
# 1/1 [==============================] - 0s 392ms/step - loss: 12.6846 - root_mean_squared_error: 3.2657 - val_loss: 11.3911 - val_root_mean_squared_error: 3.0769
# Epoch 8/20
# 1/1 [==============================] - 0s 390ms/step - loss: 11.3750 - root_mean_squared_error: 3.0743 - val_loss: 9.9877 - val_root_mean_squared_error: 2.8515
# Epoch 9/20
# 1/1 [==============================] - 0s 352ms/step - loss: 9.9660 - root_mean_squared_error: 2.8477 - val_loss: 8.5128 - val_root_mean_squared_error: 2.5879
# Epoch 10/20
# 1/1 [==============================] - 0s 314ms/step - loss: 8.4934 - root_mean_squared_error: 2.5841 - val_loss: 7.0222 - val_root_mean_squared_error: 2.2853
# Epoch 11/20
# 1/1 [==============================] - 0s 329ms/step - loss: 7.0111 - root_mean_squared_error: 2.2829 - val_loss: 5.6009 - val_root_mean_squared_error: 1.9480
# Epoch 12/20
# 1/1 [==============================] - 0s 354ms/step - loss: 5.6175 - root_mean_squared_error: 1.9523 - val_loss: 4.3673 - val_root_mean_squared_error: 1.5919
# Epoch 13/20
# 1/1 [==============================] - 0s 387ms/step - loss: 4.4371 - root_mean_squared_error: 1.6136 - val_loss: 3.4696 - val_root_mean_squared_error: 1.2621
# Epoch 14/20
# 1/1 [==============================] - 0s 383ms/step - loss: 3.6174 - root_mean_squared_error: 1.3193 - val_loss: 3.0506 - val_root_mean_squared_error: 1.0600
# Epoch 15/20
# 1/1 [==============================] - 0s 368ms/step - loss: 3.3012 - root_mean_squared_error: 1.1722 - val_loss: 3.1434 - val_root_mean_squared_error: 1.0855
# Epoch 16/20
# 1/1 [==============================] - 0s 384ms/step - loss: 3.5162 - root_mean_squared_error: 1.2455 - val_loss: 3.5346 - val_root_mean_squared_error: 1.2517
# Epoch 17/20
# 1/1 [==============================] - 0s 328ms/step - loss: 4.0135 - root_mean_squared_error: 1.4302 - val_loss: 3.8573 - val_root_mean_squared_error: 1.3887
# Epoch 18/20
# 1/1 [==============================] - 0s 338ms/step - loss: 4.3924 - root_mean_squared_error: 1.5696 - val_loss: 3.8839 - val_root_mean_squared_error: 1.4242
# Epoch 19/20
# 1/1 [==============================] - 0s 385ms/step - loss: 4.4218 - root_mean_squared_error: 1.6019 - val_loss: 3.6175 - val_root_mean_squared_error: 1.3628
# Epoch 20/20
# 1/1 [==============================] - 0s 366ms/step - loss: 4.1174 - root_mean_squared_error: 1.5353 - val_loss: 3.1880 - val_root_mean_squared_error: 1.2395
# ----Starting trial: run-2
# {'HP_NUM_UNITS': 32, 'HP_DROPOUT': 0.3, 'HP_LEARNING_RATE': 0.001, 'HP_REGULARIZER': <tensorflow.python.keras.regularizers.L2 object at 0x7fc3be6db070>}
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 18.7596 - root_mean_squared_error: 3.9270 - val_loss: 18.6922 - val_root_mean_squared_error: 3.9224
# Epoch 2/20
# 1/1 [==============================] - 0s 312ms/step - loss: 18.7030 - root_mean_squared_error: 3.9237 - val_loss: 18.6296 - val_root_mean_squared_error: 3.9183
# Epoch 3/20
# 1/1 [==============================] - 0s 332ms/step - loss: 18.6402 - root_mean_squared_error: 3.9196 - val_loss: 18.5604 - val_root_mean_squared_error: 3.9133
# Epoch 4/20
# 1/1 [==============================] - 0s 395ms/step - loss: 18.5721 - root_mean_squared_error: 3.9148 - val_loss: 18.4852 - val_root_mean_squared_error: 3.9075
# Epoch 5/20
# 1/1 [==============================] - 0s 315ms/step - loss: 18.4989 - root_mean_squared_error: 3.9092 - val_loss: 18.4056 - val_root_mean_squared_error: 3.9010
# Epoch 6/20
# 1/1 [==============================] - 0s 399ms/step - loss: 18.4215 - root_mean_squared_error: 3.9030 - val_loss: 18.3226 - val_root_mean_squared_error: 3.8941
# Epoch 7/20
# 1/1 [==============================] - 0s 345ms/step - loss: 18.3407 - root_mean_squared_error: 3.8964 - val_loss: 18.2376 - val_root_mean_squared_error: 3.8869
# Epoch 8/20
# 1/1 [==============================] - 0s 353ms/step - loss: 18.2570 - root_mean_squared_error: 3.8894 - val_loss: 18.1513 - val_root_mean_squared_error: 3.8794
# Epoch 9/20
# 1/1 [==============================] - 0s 412ms/step - loss: 18.1716 - root_mean_squared_error: 3.8820 - val_loss: 18.0644 - val_root_mean_squared_error: 3.8719
# Epoch 10/20
# 1/1 [==============================] - 0s 443ms/step - loss: 18.0853 - root_mean_squared_error: 3.8745 - val_loss: 17.9772 - val_root_mean_squared_error: 3.8642
# Epoch 11/20
# 1/1 [==============================] - 0s 383ms/step - loss: 17.9985 - root_mean_squared_error: 3.8669 - val_loss: 17.8897 - val_root_mean_squared_error: 3.8564
# Epoch 12/20
# 1/1 [==============================] - 0s 415ms/step - loss: 17.9102 - root_mean_squared_error: 3.8591 - val_loss: 17.8020 - val_root_mean_squared_error: 3.8486
# Epoch 13/20
# 1/1 [==============================] - 0s 384ms/step - loss: 17.8226 - root_mean_squared_error: 3.8512 - val_loss: 17.7140 - val_root_mean_squared_error: 3.8406
# Epoch 14/20
# 1/1 [==============================] - 0s 319ms/step - loss: 17.7347 - root_mean_squared_error: 3.8433 - val_loss: 17.6257 - val_root_mean_squared_error: 3.8326
# Epoch 15/20
# 1/1 [==============================] - 0s 295ms/step - loss: 17.6448 - root_mean_squared_error: 3.8351 - val_loss: 17.5370 - val_root_mean_squared_error: 3.8244
# Epoch 16/20
# 1/1 [==============================] - 0s 325ms/step - loss: 17.5555 - root_mean_squared_error: 3.8268 - val_loss: 17.4477 - val_root_mean_squared_error: 3.8161
# Epoch 17/20
# 1/1 [==============================] - 0s 336ms/step - loss: 17.4665 - root_mean_squared_error: 3.8185 - val_loss: 17.3577 - val_root_mean_squared_error: 3.8076
# Epoch 18/20
# 1/1 [==============================] - 0s 368ms/step - loss: 17.3752 - root_mean_squared_error: 3.8099 - val_loss: 17.2670 - val_root_mean_squared_error: 3.7990
# Epoch 19/20
# 1/1 [==============================] - 0s 389ms/step - loss: 17.2842 - root_mean_squared_error: 3.8012 - val_loss: 17.1753 - val_root_mean_squared_error: 3.7901
# Epoch 20/20
# 1/1 [==============================] - 0s 398ms/step - loss: 17.1914 - root_mean_squared_error: 3.7922 - val_loss: 17.0827 - val_root_mean_squared_error: 3.7811
# ----Starting trial: run-3
# {'HP_NUM_UNITS': 64, 'HP_DROPOUT': 0.3, 'HP_LEARNING_RATE': 0.1, 'HP_REGULARIZER': <tensorflow.python.keras.regularizers.L2 object at 0x7fc3be6db070>}
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 19.7005 - root_mean_squared_error: 3.9263 - val_loss: 10.8593 - val_root_mean_squared_error: 3.0848
# Epoch 2/20
# 1/1 [==============================] - 1s 636ms/step - loss: 10.8821 - root_mean_squared_error: 3.0885 - val_loss: 2.4060 - val_root_mean_squared_error: 1.1029
# Epoch 3/20
# 1/1 [==============================] - 1s 612ms/step - loss: 2.5463 - root_mean_squared_error: 1.1647 - val_loss: 12.7609 - val_root_mean_squared_error: 3.3101
# Epoch 4/20
# 1/1 [==============================] - 1s 503ms/step - loss: 13.5591 - root_mean_squared_error: 3.4286 - val_loss: 2.8583 - val_root_mean_squared_error: 1.1409
# Epoch 5/20
# 1/1 [==============================] - 1s 520ms/step - loss: 2.8581 - root_mean_squared_error: 1.1408 - val_loss: 6.2888 - val_root_mean_squared_error: 2.2065
# Epoch 6/20
# 1/1 [==============================] - 1s 501ms/step - loss: 6.3423 - root_mean_squared_error: 2.2186 - val_loss: 5.3427 - val_root_mean_squared_error: 2.0324
# Epoch 7/20
# 1/1 [==============================] - 0s 457ms/step - loss: 5.4591 - root_mean_squared_error: 2.0609 - val_loss: 3.3738 - val_root_mean_squared_error: 1.4976
# Epoch 8/20
# 1/1 [==============================] - 0s 427ms/step - loss: 3.5835 - root_mean_squared_error: 1.5660 - val_loss: 3.0633 - val_root_mean_squared_error: 1.3548
# Epoch 9/20
# 1/1 [==============================] - 1s 522ms/step - loss: 3.4327 - root_mean_squared_error: 1.4849 - val_loss: 3.3308 - val_root_mean_squared_error: 1.4466
# Epoch 10/20
# 1/1 [==============================] - 0s 461ms/step - loss: 3.7378 - root_mean_squared_error: 1.5810 - val_loss: 2.4083 - val_root_mean_squared_error: 1.1623
# Epoch 11/20
# 1/1 [==============================] - 1s 527ms/step - loss: 2.6639 - root_mean_squared_error: 1.2675 - val_loss: 2.1282 - val_root_mean_squared_error: 1.1343
# Epoch 12/20
# 1/1 [==============================] - 0s 496ms/step - loss: 2.2326 - root_mean_squared_error: 1.1795 - val_loss: 2.5749 - val_root_mean_squared_error: 1.3696
# Epoch 13/20
# 1/1 [==============================] - 0s 497ms/step - loss: 2.6108 - root_mean_squared_error: 1.3826 - val_loss: 2.5101 - val_root_mean_squared_error: 1.3715
# Epoch 14/20
# 1/1 [==============================] - 0s 428ms/step - loss: 2.5211 - root_mean_squared_error: 1.3755 - val_loss: 1.8137 - val_root_mean_squared_error: 1.0979
# Epoch 15/20
# 1/1 [==============================] - 0s 431ms/step - loss: 1.8118 - root_mean_squared_error: 1.0970 - val_loss: 1.4908 - val_root_mean_squared_error: 0.9320
# Epoch 16/20
# 1/1 [==============================] - 0s 477ms/step - loss: 1.5011 - root_mean_squared_error: 0.9375 - val_loss: 1.8903 - val_root_mean_squared_error: 1.1316
# Epoch 17/20
# 1/1 [==============================] - 0s 450ms/step - loss: 1.9239 - root_mean_squared_error: 1.1463 - val_loss: 1.5726 - val_root_mean_squared_error: 1.0326
# Epoch 18/20
# 1/1 [==============================] - 0s 430ms/step - loss: 1.5727 - root_mean_squared_error: 1.0326 - val_loss: 1.2586 - val_root_mean_squared_error: 0.9352
# Epoch 19/20
# 1/1 [==============================] - 0s 439ms/step - loss: 1.2099 - root_mean_squared_error: 0.9088 - val_loss: 1.5861 - val_root_mean_squared_error: 1.1246
# Epoch 20/20
# 1/1 [==============================] - 0s 492ms/step - loss: 1.5344 - root_mean_squared_error: 1.1015 - val_loss: 1.6570 - val_root_mean_squared_error: 1.1578
# ----Starting trial: run-4
# {'HP_NUM_UNITS': 64, 'HP_DROPOUT': 0.3, 'HP_LEARNING_RATE': 0.01, 'HP_REGULARIZER': <tensorflow.python.keras.regularizers.L2 object at 0x7fc3be6db070>}
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 19.6647 - root_mean_squared_error: 3.9207 - val_loss: 18.5278 - val_root_mean_squared_error: 3.8347
# Epoch 2/20
# 1/1 [==============================] - 0s 432ms/step - loss: 18.5529 - root_mean_squared_error: 3.8379 - val_loss: 17.4085 - val_root_mean_squared_error: 3.7426
# Epoch 3/20
# 1/1 [==============================] - 1s 514ms/step - loss: 17.4285 - root_mean_squared_error: 3.7453 - val_loss: 16.2576 - val_root_mean_squared_error: 3.6371
# Epoch 4/20
# 1/1 [==============================] - 1s 594ms/step - loss: 16.2745 - root_mean_squared_error: 3.6394 - val_loss: 15.0332 - val_root_mean_squared_error: 3.5103
# Epoch 5/20
# 1/1 [==============================] - 0s 450ms/step - loss: 15.0435 - root_mean_squared_error: 3.5118 - val_loss: 13.7031 - val_root_mean_squared_error: 3.3550
# Epoch 6/20
# 1/1 [==============================] - 0s 474ms/step - loss: 13.7068 - root_mean_squared_error: 3.3556 - val_loss: 12.2487 - val_root_mean_squared_error: 3.1646
# Epoch 7/20
# 1/1 [==============================] - 0s 461ms/step - loss: 12.2448 - root_mean_squared_error: 3.1640 - val_loss: 10.6713 - val_root_mean_squared_error: 2.9329
# Epoch 8/20
# 1/1 [==============================] - 0s 464ms/step - loss: 10.6564 - root_mean_squared_error: 2.9303 - val_loss: 8.9973 - val_root_mean_squared_error: 2.6547
# Epoch 9/20
# 1/1 [==============================] - 0s 433ms/step - loss: 8.9748 - root_mean_squared_error: 2.6504 - val_loss: 7.2861 - val_root_mean_squared_error: 2.3266
# Epoch 10/20
# 1/1 [==============================] - 0s 434ms/step - loss: 7.2642 - root_mean_squared_error: 2.3219 - val_loss: 5.6422 - val_root_mean_squared_error: 1.9511
# Epoch 11/20
# 1/1 [==============================] - 0s 445ms/step - loss: 5.6279 - root_mean_squared_error: 1.9474 - val_loss: 4.2295 - val_root_mean_squared_error: 1.5475
# Epoch 12/20
# 1/1 [==============================] - 0s 423ms/step - loss: 4.2428 - root_mean_squared_error: 1.5518 - val_loss: 3.2710 - val_root_mean_squared_error: 1.1862
# Epoch 13/20
# 1/1 [==============================] - 0s 408ms/step - loss: 3.3326 - root_mean_squared_error: 1.2119 - val_loss: 2.9828 - val_root_mean_squared_error: 1.0378
# Epoch 14/20
# 1/1 [==============================] - 0s 457ms/step - loss: 3.1258 - root_mean_squared_error: 1.1046 - val_loss: 3.3380 - val_root_mean_squared_error: 1.1887
# Epoch 15/20
# 1/1 [==============================] - 1s 678ms/step - loss: 3.5701 - root_mean_squared_error: 1.2826 - val_loss: 3.8644 - val_root_mean_squared_error: 1.4042
# Epoch 16/20
# 1/1 [==============================] - 1s 549ms/step - loss: 4.1538 - root_mean_squared_error: 1.5037 - val_loss: 4.0567 - val_root_mean_squared_error: 1.4984
# Epoch 17/20
# 1/1 [==============================] - 0s 432ms/step - loss: 4.3592 - root_mean_squared_error: 1.5961 - val_loss: 3.8051 - val_root_mean_squared_error: 1.4515
# Epoch 18/20
# 1/1 [==============================] - 0s 435ms/step - loss: 4.0742 - root_mean_squared_error: 1.5414 - val_loss: 3.2834 - val_root_mean_squared_error: 1.3097
# Epoch 19/20
# 1/1 [==============================] - 1s 525ms/step - loss: 3.4935 - root_mean_squared_error: 1.3876 - val_loss: 2.7215 - val_root_mean_squared_error: 1.1353
# Epoch 20/20
# 1/1 [==============================] - 0s 453ms/step - loss: 2.8652 - root_mean_squared_error: 1.1970 - val_loss: 2.2825 - val_root_mean_squared_error: 0.9909
# ----Starting trial: run-5
# {'HP_NUM_UNITS': 64, 'HP_DROPOUT': 0.3, 'HP_LEARNING_RATE': 0.001, 'HP_REGULARIZER': <tensorflow.python.keras.regularizers.L2 object at 0x7fc3be6db070>}
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 19.5077 - root_mean_squared_error: 3.9078 - val_loss: 19.3722 - val_root_mean_squared_error: 3.8965
# Epoch 2/20
# 1/1 [==============================] - 1s 578ms/step - loss: 19.3975 - root_mean_squared_error: 3.8997 - val_loss: 19.2571 - val_root_mean_squared_error: 3.8877
# Epoch 3/20
# 1/1 [==============================] - 1s 536ms/step - loss: 19.2835 - root_mean_squared_error: 3.8911 - val_loss: 19.1404 - val_root_mean_squared_error: 3.8786
# Epoch 4/20
# 1/1 [==============================] - 1s 560ms/step - loss: 19.1670 - root_mean_squared_error: 3.8821 - val_loss: 19.0229 - val_root_mean_squared_error: 3.8694
# Epoch 5/20
# 1/1 [==============================] - 1s 540ms/step - loss: 19.0491 - root_mean_squared_error: 3.8728 - val_loss: 18.9047 - val_root_mean_squared_error: 3.8600
# Epoch 6/20
# 1/1 [==============================] - 0s 498ms/step - loss: 18.9297 - root_mean_squared_error: 3.8632 - val_loss: 18.7859 - val_root_mean_squared_error: 3.8504
# Epoch 7/20
# 1/1 [==============================] - 1s 550ms/step - loss: 18.8103 - root_mean_squared_error: 3.8535 - val_loss: 18.6665 - val_root_mean_squared_error: 3.8406
# Epoch 8/20
# 1/1 [==============================] - 1s 564ms/step - loss: 18.6905 - root_mean_squared_error: 3.8437 - val_loss: 18.5463 - val_root_mean_squared_error: 3.8307
# Epoch 9/20
# 1/1 [==============================] - 0s 471ms/step - loss: 18.5693 - root_mean_squared_error: 3.8337 - val_loss: 18.4254 - val_root_mean_squared_error: 3.8205
# Epoch 10/20
# 1/1 [==============================] - 0s 481ms/step - loss: 18.4479 - root_mean_squared_error: 3.8235 - val_loss: 18.3036 - val_root_mean_squared_error: 3.8102
# Epoch 11/20
# 1/1 [==============================] - 0s 416ms/step - loss: 18.3256 - root_mean_squared_error: 3.8131 - val_loss: 18.1808 - val_root_mean_squared_error: 3.7996
# Epoch 12/20
# 1/1 [==============================] - 0s 455ms/step - loss: 18.2015 - root_mean_squared_error: 3.8023 - val_loss: 18.0570 - val_root_mean_squared_error: 3.7888
# Epoch 13/20
# 1/1 [==============================] - 1s 528ms/step - loss: 18.0769 - root_mean_squared_error: 3.7914 - val_loss: 17.9321 - val_root_mean_squared_error: 3.7776
# Epoch 14/20
# 1/1 [==============================] - 0s 463ms/step - loss: 17.9520 - root_mean_squared_error: 3.7803 - val_loss: 17.8059 - val_root_mean_squared_error: 3.7663
# Epoch 15/20
# 1/1 [==============================] - 0s 437ms/step - loss: 17.8250 - root_mean_squared_error: 3.7688 - val_loss: 17.6784 - val_root_mean_squared_error: 3.7546
# Epoch 16/20
# 1/1 [==============================] - 1s 523ms/step - loss: 17.6969 - root_mean_squared_error: 3.7570 - val_loss: 17.5494 - val_root_mean_squared_error: 3.7426
# Epoch 17/20
# 1/1 [==============================] - 1s 508ms/step - loss: 17.5672 - root_mean_squared_error: 3.7449 - val_loss: 17.4188 - val_root_mean_squared_error: 3.7302
# Epoch 18/20
# 1/1 [==============================] - 0s 444ms/step - loss: 17.4362 - root_mean_squared_error: 3.7325 - val_loss: 17.2866 - val_root_mean_squared_error: 3.7175
# Epoch 19/20
# 1/1 [==============================] - 0s 444ms/step - loss: 17.3026 - root_mean_squared_error: 3.7196 - val_loss: 17.1526 - val_root_mean_squared_error: 3.7043
# Epoch 20/20
# 1/1 [==============================] - 1s 528ms/step - loss: 17.1685 - root_mean_squared_error: 3.7065 - val_loss: 17.0167 - val_root_mean_squared_error: 3.6908
# ----Starting trial: run-6
# {'HP_NUM_UNITS': 128, 'HP_DROPOUT': 0.3, 'HP_LEARNING_RATE': 0.1, 'HP_REGULARIZER': <tensorflow.python.keras.regularizers.L2 object at 0x7fc3be6db070>}
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 20.5814 - root_mean_squared_error: 3.9221 - val_loss: 7.6342 - val_root_mean_squared_error: 2.4658
# Epoch 2/20
# 1/1 [==============================] - 1s 647ms/step - loss: 7.6546 - root_mean_squared_error: 2.4699 - val_loss: 15.4030 - val_root_mean_squared_error: 3.6283
# Epoch 3/20
# 1/1 [==============================] - 1s 642ms/step - loss: 16.3108 - root_mean_squared_error: 3.7513 - val_loss: 5.8129 - val_root_mean_squared_error: 1.8835
# Epoch 4/20
# 1/1 [==============================] - 1s 683ms/step - loss: 5.8699 - root_mean_squared_error: 1.8986 - val_loss: 7.2755 - val_root_mean_squared_error: 2.2522
# Epoch 5/20
# 1/1 [==============================] - 1s 682ms/step - loss: 7.3662 - root_mean_squared_error: 2.2722 - val_loss: 4.4347 - val_root_mean_squared_error: 1.5596
# Epoch 6/20
# 1/1 [==============================] - 1s 766ms/step - loss: 4.5247 - root_mean_squared_error: 1.5882 - val_loss: 3.5799 - val_root_mean_squared_error: 1.2481
# Epoch 7/20
# 1/1 [==============================] - 1s 786ms/step - loss: 3.7618 - root_mean_squared_error: 1.3189 - val_loss: 4.2220 - val_root_mean_squared_error: 1.4635
# Epoch 8/20
# 1/1 [==============================] - 1s 645ms/step - loss: 4.4499 - root_mean_squared_error: 1.5394 - val_loss: 3.1716 - val_root_mean_squared_error: 1.0917
# Epoch 9/20
# 1/1 [==============================] - 1s 669ms/step - loss: 3.2863 - root_mean_squared_error: 1.1431 - val_loss: 3.3990 - val_root_mean_squared_error: 1.2492
# Epoch 10/20
# 1/1 [==============================] - 1s 666ms/step - loss: 3.4147 - root_mean_squared_error: 1.2555 - val_loss: 3.9722 - val_root_mean_squared_error: 1.5063
# Epoch 11/20
# 1/1 [==============================] - 1s 676ms/step - loss: 3.9478 - root_mean_squared_error: 1.4982 - val_loss: 3.0952 - val_root_mean_squared_error: 1.2299
# Epoch 12/20
# 1/1 [==============================] - 1s 663ms/step - loss: 3.0541 - root_mean_squared_error: 1.2131 - val_loss: 2.4034 - val_root_mean_squared_error: 0.9472
# Epoch 13/20
# 1/1 [==============================] - 1s 634ms/step - loss: 2.3773 - root_mean_squared_error: 0.9333 - val_loss: 2.8815 - val_root_mean_squared_error: 1.2223
# Epoch 14/20
# 1/1 [==============================] - 1s 662ms/step - loss: 2.8895 - root_mean_squared_error: 1.2256 - val_loss: 2.1290 - val_root_mean_squared_error: 1.0075
# Epoch 15/20
# 1/1 [==============================] - 1s 707ms/step - loss: 2.0893 - root_mean_squared_error: 0.9876 - val_loss: 1.8669 - val_root_mean_squared_error: 1.0179
# Epoch 16/20
# 1/1 [==============================] - 1s 640ms/step - loss: 1.7919 - root_mean_squared_error: 0.9804 - val_loss: 2.2283 - val_root_mean_squared_error: 1.2480
# Epoch 17/20
# 1/1 [==============================] - 1s 676ms/step - loss: 2.1492 - root_mean_squared_error: 1.2159 - val_loss: 1.9731 - val_root_mean_squared_error: 1.1562
# Epoch 18/20
# 1/1 [==============================] - 1s 627ms/step - loss: 1.8984 - root_mean_squared_error: 1.1235 - val_loss: 1.5286 - val_root_mean_squared_error: 0.9215
# Epoch 19/20
# 1/1 [==============================] - 1s 667ms/step - loss: 1.4601 - root_mean_squared_error: 0.8835 - val_loss: 1.8158 - val_root_mean_squared_error: 1.0496
# Epoch 20/20
# 1/1 [==============================] - 1s 713ms/step - loss: 1.7697 - root_mean_squared_error: 1.0274 - val_loss: 1.6605 - val_root_mean_squared_error: 1.0129
# ----Starting trial: run-7
# {'HP_NUM_UNITS': 128, 'HP_DROPOUT': 0.3, 'HP_LEARNING_RATE': 0.01, 'HP_REGULARIZER': <tensorflow.python.keras.regularizers.L2 object at 0x7fc3be6db070>}
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 20.5050 - root_mean_squared_error: 3.9239 - val_loss: 18.9978 - val_root_mean_squared_error: 3.8219
# Epoch 2/20
# 1/1 [==============================] - 1s 692ms/step - loss: 19.0226 - root_mean_squared_error: 3.8251 - val_loss: 17.5176 - val_root_mean_squared_error: 3.7094
# Epoch 3/20
# 1/1 [==============================] - 1s 697ms/step - loss: 17.5378 - root_mean_squared_error: 3.7121 - val_loss: 15.9822 - val_root_mean_squared_error: 3.5736
# Epoch 4/20
# 1/1 [==============================] - 1s 580ms/step - loss: 15.9988 - root_mean_squared_error: 3.5759 - val_loss: 14.3539 - val_root_mean_squared_error: 3.4059
# Epoch 5/20
# 1/1 [==============================] - 1s 615ms/step - loss: 14.3626 - root_mean_squared_error: 3.4072 - val_loss: 12.6063 - val_root_mean_squared_error: 3.1971
# Epoch 6/20
# 1/1 [==============================] - 1s 659ms/step - loss: 12.6056 - root_mean_squared_error: 3.1970 - val_loss: 10.7265 - val_root_mean_squared_error: 2.9368
# Epoch 7/20
# 1/1 [==============================] - 1s 648ms/step - loss: 10.7100 - root_mean_squared_error: 2.9340 - val_loss: 8.7355 - val_root_mean_squared_error: 2.6144
# Epoch 8/20
# 1/1 [==============================] - 1s 625ms/step - loss: 8.7070 - root_mean_squared_error: 2.6089 - val_loss: 6.7177 - val_root_mean_squared_error: 2.2229
# Epoch 9/20
# 1/1 [==============================] - 1s 648ms/step - loss: 6.6786 - root_mean_squared_error: 2.2141 - val_loss: 4.8520 - val_root_mean_squared_error: 1.7687
# Epoch 10/20
# 1/1 [==============================] - 1s 636ms/step - loss: 4.8143 - root_mean_squared_error: 1.7580 - val_loss: 3.4393 - val_root_mean_squared_error: 1.3061
# Epoch 11/20
# 1/1 [==============================] - 1s 595ms/step - loss: 3.4246 - root_mean_squared_error: 1.3004 - val_loss: 2.8686 - val_root_mean_squared_error: 1.0411
# Epoch 12/20
# 1/1 [==============================] - 1s 630ms/step - loss: 2.9052 - root_mean_squared_error: 1.0585 - val_loss: 3.2783 - val_root_mean_squared_error: 1.2066
# Epoch 13/20
# 1/1 [==============================] - 1s 691ms/step - loss: 3.3862 - root_mean_squared_error: 1.2505 - val_loss: 3.9847 - val_root_mean_squared_error: 1.4830
# Epoch 14/20
# 1/1 [==============================] - 1s 703ms/step - loss: 4.1413 - root_mean_squared_error: 1.5349 - val_loss: 4.1567 - val_root_mean_squared_error: 1.5745
# Epoch 15/20
# 1/1 [==============================] - 1s 599ms/step - loss: 4.3167 - root_mean_squared_error: 1.6245 - val_loss: 3.7104 - val_root_mean_squared_error: 1.4769
# Epoch 16/20
# 1/1 [==============================] - 1s 639ms/step - loss: 3.8236 - root_mean_squared_error: 1.5148 - val_loss: 2.9921 - val_root_mean_squared_error: 1.2757
# Epoch 17/20
# 1/1 [==============================] - 1s 611ms/step - loss: 3.0535 - root_mean_squared_error: 1.2996 - val_loss: 2.3451 - val_root_mean_squared_error: 1.0692
# Epoch 18/20
# 1/1 [==============================] - 1s 672ms/step - loss: 2.3575 - root_mean_squared_error: 1.0750 - val_loss: 1.9487 - val_root_mean_squared_error: 0.9461
# Epoch 19/20
# 1/1 [==============================] - 1s 682ms/step - loss: 1.9282 - root_mean_squared_error: 0.9352 - val_loss: 1.8184 - val_root_mean_squared_error: 0.9439
# Epoch 20/20
# 1/1 [==============================] - 1s 594ms/step - loss: 1.7747 - root_mean_squared_error: 0.9205 - val_loss: 1.8744 - val_root_mean_squared_error: 1.0237
# ----Starting trial: run-8
# {'HP_NUM_UNITS': 128, 'HP_DROPOUT': 0.3, 'HP_LEARNING_RATE': 0.001, 'HP_REGULARIZER': <tensorflow.python.keras.regularizers.L2 object at 0x7fc3be6db070>}
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 20.3967 - root_mean_squared_error: 3.9226 - val_loss: 20.2375 - val_root_mean_squared_error: 3.9116
# Epoch 2/20
# 1/1 [==============================] - 1s 631ms/step - loss: 20.2621 - root_mean_squared_error: 3.9148 - val_loss: 20.0907 - val_root_mean_squared_error: 3.9021
# Epoch 3/20
# 1/1 [==============================] - 1s 606ms/step - loss: 20.1179 - root_mean_squared_error: 3.9056 - val_loss: 19.9413 - val_root_mean_squared_error: 3.8922
# Epoch 4/20
# 1/1 [==============================] - 1s 657ms/step - loss: 19.9699 - root_mean_squared_error: 3.8959 - val_loss: 19.7919 - val_root_mean_squared_error: 3.8821
# Epoch 5/20
# 1/1 [==============================] - 1s 677ms/step - loss: 19.8203 - root_mean_squared_error: 3.8857 - val_loss: 19.6430 - val_root_mean_squared_error: 3.8719
# Epoch 6/20
# 1/1 [==============================] - 1s 646ms/step - loss: 19.6707 - root_mean_squared_error: 3.8755 - val_loss: 19.4945 - val_root_mean_squared_error: 3.8616
# Epoch 7/20
# 1/1 [==============================] - 1s 600ms/step - loss: 19.5220 - root_mean_squared_error: 3.8652 - val_loss: 19.3465 - val_root_mean_squared_error: 3.8512
# Epoch 8/20
# 1/1 [==============================] - 1s 562ms/step - loss: 19.3730 - root_mean_squared_error: 3.8547 - val_loss: 19.1986 - val_root_mean_squared_error: 3.8408
# Epoch 9/20
# 1/1 [==============================] - 1s 692ms/step - loss: 19.2246 - root_mean_squared_error: 3.8441 - val_loss: 19.0508 - val_root_mean_squared_error: 3.8301
# Epoch 10/20
# 1/1 [==============================] - 1s 646ms/step - loss: 19.0763 - root_mean_squared_error: 3.8334 - val_loss: 18.9029 - val_root_mean_squared_error: 3.8193
# Epoch 11/20
# 1/1 [==============================] - 1s 657ms/step - loss: 18.9277 - root_mean_squared_error: 3.8225 - val_loss: 18.7546 - val_root_mean_squared_error: 3.8083
# Epoch 12/20
# 1/1 [==============================] - 1s 566ms/step - loss: 18.7794 - root_mean_squared_error: 3.8115 - val_loss: 18.6058 - val_root_mean_squared_error: 3.7970
# Epoch 13/20
# 1/1 [==============================] - 1s 648ms/step - loss: 18.6305 - root_mean_squared_error: 3.8002 - val_loss: 18.4563 - val_root_mean_squared_error: 3.7854
# Epoch 14/20
# 1/1 [==============================] - 1s 609ms/step - loss: 18.4803 - root_mean_squared_error: 3.7886 - val_loss: 18.3058 - val_root_mean_squared_error: 3.7736
# Epoch 15/20
# 1/1 [==============================] - 1s 676ms/step - loss: 18.3294 - root_mean_squared_error: 3.7767 - val_loss: 18.1541 - val_root_mean_squared_error: 3.7614
# Epoch 16/20
# 1/1 [==============================] - 1s 667ms/step - loss: 18.1771 - root_mean_squared_error: 3.7645 - val_loss: 18.0010 - val_root_mean_squared_error: 3.7488
# Epoch 17/20
# 1/1 [==============================] - 1s 641ms/step - loss: 18.0230 - root_mean_squared_error: 3.7518 - val_loss: 17.8463 - val_root_mean_squared_error: 3.7359
# Epoch 18/20
# 1/1 [==============================] - 1s 579ms/step - loss: 17.8685 - root_mean_squared_error: 3.7388 - val_loss: 17.6898 - val_root_mean_squared_error: 3.7224
# Epoch 19/20
# 1/1 [==============================] - 1s 643ms/step - loss: 17.7111 - root_mean_squared_error: 3.7253 - val_loss: 17.5314 - val_root_mean_squared_error: 3.7085
# Epoch 20/20
# 1/1 [==============================] - 1s 624ms/step - loss: 17.5524 - root_mean_squared_error: 3.7114 - val_loss: 17.3707 - val_root_mean_squared_error: 3.6941

# %%
import matplotlib.pyplot as plt

# %%
len(run_history.keys())
# Out:
# 9

# %%
fig, axs = plt.subplots(ncols=2, nrows=len(run_history.keys()), figsize=(10, len(run_history.keys())*3))

for n, key in enumerate(run_history.keys()):
    axs[n,0].plot(run_history[key]['output'].history['loss'], color='r')
    axs[n,0].plot(run_history[key]['output'].history['val_loss'], color='b')
    
    axs[n,1].plot(run_history[key]['output'].history['root_mean_squared_error'], color='r')
    axs[n,1].plot(run_history[key]['output'].history['val_root_mean_squared_error'], color='b')
    
    title_str = '-'.join(str(run_history[key]['params'][param]) for param in run_history[key]['params'].keys())
    
    axs[n,0].set_title("mse {}".format(key))
    axs[n,1].set_title("rmse {}".format(key))
    
    axs[n,0].set_ylim(0,10)
    axs[n,1].set_ylim(0,5)
    
    axs[n, 1].axhline(1, color='k', lw=1)
    
plt.tight_layout()   
plt.show()

# %%
print(run_history['run-0'])
print(run_history['run-3'])
print(run_history['run-6'])
# Out:
# {'params': {'HP_NUM_UNITS': 32, 'HP_DROPOUT': 0.3, 'HP_LEARNING_RATE': 0.1, 'HP_REGULARIZER': <tensorflow.python.keras.regularizers.L2 object at 0x7fc3be6db070>}, 'output': <tensorflow.python.keras.callbacks.History object at 0x7fc3c209d790>}
# {'params': {'HP_NUM_UNITS': 64, 'HP_DROPOUT': 0.3, 'HP_LEARNING_RATE': 0.1, 'HP_REGULARIZER': <tensorflow.python.keras.regularizers.L2 object at 0x7fc3be6db070>}, 'output': <tensorflow.python.keras.callbacks.History object at 0x7fc3902b80d0>}
# {'params': {'HP_NUM_UNITS': 128, 'HP_DROPOUT': 0.3, 'HP_LEARNING_RATE': 0.1, 'HP_REGULARIZER': <tensorflow.python.keras.regularizers.L2 object at 0x7fc3be6db070>}, 'output': <tensorflow.python.keras.callbacks.History object at 0x7fc3706ad490>}

# %%
run_history['run-6']
# Out:
# {'params': {'HP_NUM_UNITS': 128,
#   'HP_DROPOUT': 0.3,
#   'HP_LEARNING_RATE': 0.1,
#   'HP_REGULARIZER': <tensorflow.python.keras.regularizers.L2 at 0x7fc3be6db070>},
#  'output': <tensorflow.python.keras.callbacks.History at 0x7fc3706ad490>}

# %%
run_history['run-6']['params']['HP_REGULARIZER'].l2
# Out:
# array(0.1, dtype=float32)

# %%
fig, ax = plt.subplots(figsize=(8,6))

colors = ['red', 'blue', 'green']
for n, key in enumerate(['run-0', 'run-3', 'run-6']):
    
    ax.plot(run_history[key]['output'].history['val_root_mean_squared_error'], color=colors[n], alpha=.8, lw=2)

ax.set_ylim(0,5)
plt.show()

# %%
# Out:
# {'params': {'HP_NUM_UNITS': 64,
#   'HP_DROPOUT': 0.3,
#   'HP_LEARNING_RATE': 0.1,
#   'HP_REGULARIZER': <tensorflow.python.keras.regularizers.L2 at 0x7fc3be6db070>},
#  'output': <tensorflow.python.keras.callbacks.History at 0x7fc3902b80d0>}

# %%
run_history['run-0']['params']['HP_REGULARIZER'].l2
# Out:
# array(0.1, dtype=float32)

# %%
run_history['run-1']
# Out:
# {'params': {'HP_NUM_UNITS': 64,
#   'HP_DROPOUT': 0.3,
#   'HP_LEARNING_RATE': 0.01,
#   'HP_REGULARIZER': 'l2'},
#  'output': <tensorflow.python.keras.callbacks.History at 0x7f4efc4fe4f0>}

# %%
run_history['run-1']['params']['HP_REGULARIZER'].l2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-247deaf7f870> in <module>
# ----> 1 run_history['run-1']['params']['HP_REGULARIZER'].l2
#
# AttributeError: 'str' object has no attribute 'l2'

# %%
import json
def export_history(run_history, batch_size, n_epochs, save_path):
    history_dict = run_history.copy()
    for key in history_dict:
        if history_dict[key]['params']['HP_REGULARIZER']=='l2':
            
            history_dict[key]['params']['HP_REGULARIZER'] = .01
        else:
            try:
                history_dict[key]['params']['HP_REGULARIZER'] = history_dict[key]['params']['HP_REGULARIZER'].l2.tolist()
            except:
                pass   
        if type(history_dict[key]['params']['HP_REGULARIZER']) == np.ndarray:
            history_dict[key]['params']['HP_REGULARIZER'] = history_dict[key]['params']['HP_REGULARIZER'].tolist()
        history_dict[key]['params']['batch_size'] = batch_size
        history_dict[key]['params']['n_epochs'] = n_epochs
        
        try:
            history_dict[key]['output'] = history_dict[key]['output'].history
        except:
            history_dict[key]['output'] = history_dict[key]['output']
      
    with open(save_path, 'w') as f:
        json.dump(history_dict, f)
    
    return history_dict

new_dict = export_history(run_history, len(X_train), 20, "./run_history/model5.json")
